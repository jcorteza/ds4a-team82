# %%
import pandas as pd

# %%
files = ['NDECoreExcel_Mathematics, Grade 4, All students_20201130082407', 'NDECoreExcel_Reading, Grade 4, All students_20201130082403', 'NDECoreExcel_Science, Grade 4, All students - 2_20201130082433', 'NDECoreExcel_Vocabulary, Grade 4, All students_20201130082411', 'NDECoreExcel_Writing, Grade 4, All students - 2_20201130082430']
subject = ['Mathematics', 'Reading', 'Science', 'Vocabulary', 'Writing']

# %%
#Code to read in the NDECoreExcel_SUBJECT, Grade 4, All students_##############.Xls files

ndecore_m_all = pd.read_excel('NDECoreExcel_Mathematics, Grade 4, All students_20201130082407.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

ndecore_r_all = pd.read_excel('NDECoreExcel_Reading, Grade 4, All students_20201130082403.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

ndecore_s_all = pd.read_excel('NDECoreExcel_Science, Grade 4, All students - 2_20201130082433.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

ndecore_v_all = pd.read_excel('NDECoreExcel_Vocabulary, Grade 4, All students_20201130082411.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

ndecore_w_all = pd.read_excel('NDECoreExcel_Writing, Grade 4, All students - 2_20201130082430.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

# %%
#Code to read in the NDECoreExcel_SUBJECT, Grade 4, National School Lunch Program el_##############.Xls files

ndecore_m_lunch = pd.read_excel('NDECoreExcel_Mathematics, Grade 4, National School Lunch Progra_20201130082409.Xls', header = 8, usecols = 'A:D', skipfooter = 5)

ndecore_r_lunch = pd.read_excel('NDECoreExcel_Reading, Grade 4, National School Lunch Program el_20201130082407.Xls', header = 8, usecols = 'A:D', skipfooter = 5)

ndecore_s_lunch = pd.read_excel('NDECoreExcel_Science, Grade 4, National School Lunch Program el_20201130082429.Xls', header = 8, usecols = 'A:D', skipfooter = 5)

ndecore_v_lunch = pd.read_excel('NDECoreExcel_Vocabulary, Grade 4, National School Lunch Program_20201130082417.Xls', header = 8, usecols = 'A:D', skipfooter = 5)

ndecore_w_lunch = pd.read_excel('NDECoreExcel_Writing, Grade 4, National School Lunch Program el_20201130082422.Xls', header = 8, usecols = 'A:D', skipfooter = 5)

# %%
#Code to read in the NDECoreExcel_SUBJECT, Grade 4, All students_##############.Xls files by STATE

state_m = pd.read_excel('NDECoreExcel_Mathematics, Grade 4, All students_20201130083415.Xls', header = 8, usecols = 'A:D', skipfooter = 6).dropna()

state_r = pd.read_excel('NDECoreExcel_Reading, Grade 4, All students_20201130083518.Xls', header = 8, usecols = 'A:D', skipfooter = 6).dropna()

state_s = pd.read_excel('NDECoreExcel_Science, Grade 4, All students - 2_20201130083640.Xls', header = 8, usecols = 'A:D', skipfooter = 5).dropna()

state_v = pd.read_excel('NDECoreExcel_Vocabulary, Grade 4, All students_20201130083705.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

state_w = pd.read_excel('NDECoreExcel_Writing, Grade 4, All students_20201130083707.Xls', header = 8, usecols = 'A:D', skipfooter = 3).dropna()

# %%
#Code to read in the NDECoreExcel_SUBJECT, Grade 4, National School Lunch Program el_##############.Xls files by STATE

state_m_lunch = pd.read_excel('NDECoreExcel_Mathematics, Grade 4, National School Lunch Progra_20201130083516.Xls', header = 8, usecols = 'A:D', skipfooter = 7).dropna()

state_r_lunch = pd.read_excel('NDECoreExcel_Reading, Grade 4, National School Lunch Program el_20201130083619.Xls', header = 8, usecols = 'A:D', skipfooter = 7).dropna()

state_s_lunch = pd.read_excel('NDECoreExcel_Science, Grade 4, National School Lunch Program el_20201130083651.Xls', header = 8, usecols = 'A:D', skipfooter = 7).dropna()

state_v_lunch = pd.read_excel('NDECoreExcel_Vocabulary, Grade 4, National School Lunch Program_20201130083706.Xls', header = 8, usecols = 'A:D', skipfooter = 4).dropna()

# %%
state_m_lunch
# Out:
#        Year     Jurisdiction  \
# 0      2019  National public
# 1      2019  National public
# 2      2019  National public
# 3      2019  National public
# 4      2019  National public
# 5      2019  National public
# 6      2019          Alabama
# 7      2019          Alabama
# 8      2019          Alabama
# 9      2019          Alabama
# 10     2019          Alabama
# 11     2019          Alabama
# 12     2019           Alaska
# 13     2019           Alaska
# 14     2019           Alaska
# 15     2019           Alaska
# 16     2019           Alaska
# 17     2019           Alaska
# 18     2019          Arizona
# 19     2019          Arizona
# 20     2019          Arizona
# 21     2019          Arizona
# 22     2019          Arizona
# 23     2019          Arizona
# 24     2019         Arkansas
# 25     2019         Arkansas
# 26     2019         Arkansas
# 27     2019         Arkansas
# 28     2019         Arkansas
# 29     2019         Arkansas
# ...     ...              ...
# ...
